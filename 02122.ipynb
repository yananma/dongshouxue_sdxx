# %% [markdown]
# <a href="https://colab.research.google.com/github/yananma/5_programs_per_day/blob/master/02122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 9.5 多尺度目标检测

# %%
# !git clone https://github.com/d2l-ai/d2l-zh.git

# %%
# %matplotlib inline 
from PIL import Image 
import numpy as np 
import torch 
import d2l 

img = Image.open('d2l-zh/img/catdog.jpg')
w, h = img.size

# %%
d2l.set_figsize(figsize=(5, 3.5))

def display_anchors(fmap_w, fmap_h, s):
    fmap = torch.zeros((1, 10, fmap_h, fmap_w), dtype=torch.float32)
    offset_x, offset_y = 1.0 / fmap_w, 1.0 / fmap_h
    anchors = d2l.MultiBoxPrior(fmap, sizes=s, ratios=[1, 2, 0.5]) + \
        torch.tensor([offset_x/2, offset_y/2, offset_x/2, offset_y/2])
    bbox_scale = torch.tensor([[w, h, w, h]], dtype=torch.float32)
    d2l.show_bboxes(d2l.plt.imshow(img).axes, 
            anchors[0] * bbox_scale)

# %%
display_anchors(fmap_w=4, fmap_h=2, s=[0.15])

# %%
display_anchors(fmap_w=2, fmap_h=1, s=[0.4])

# %%
display_anchors(fmap_w=1, fmap_h=1, s=[0.8])
